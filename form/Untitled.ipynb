# %%
from form import Ui_MultiPrint
from PyQt5 import QtWidgets,QtGui,QtCore
import sys
from opengl.gl_widget import GLWidget
from widget.Axis import Drawing
from widget.Inject import Inject
from widget.ToolBar import ToolBar
from widget.Graph import graph
from dialog.parasettings import Ui_Parasettings
from numpy import array
import numpy as np
import pronsole
import datetime
import pyqtgraph as pg
from pyqtgraph import GraphicsLayoutWidget
class ParaDialog(QtWidgets.QDialog,Ui_Parasettings):
    def __init__(self):
        super(ParaDialog,self).__init__()
        self.setupUi(self)
class myform(Ui_MultiPrint,QtWidgets.QWidget):
    def __init__(self):
        super(myform,self).__init__()
        self.setupUi(self)
        
        self.register=True#判定是否注册
        self.register_time=True#判定是否在注册日期之内
        self.firstImport=True#第一次导入文件
        self.timesecond=0#加工时间
        self.tick=0#温度曲线x点
        self.chan_1=True#选择通道1
        self.chan_2=False#选择通道2
        self.chan_both=False#选择混合通道
        self.start_time=datetime.datetime.now()#软件启动的时间点
        self.finish=False
        #self.data_temperature=[2,1,5,4,5,6,4,3,4,4,7,12,14,2,152,1,21,5,1,0,2,1,21,1,2,12,1,2,1,21,2,1,54,2,1]
        #初始化工具栏
        self.initToolBar()
        
        #初始化显示区
        self.initshow()
        
        
        #初始化左侧显示区
        self.initInject()
        
        #监控环境状态
        self.enviroment_monitor=QtCore.QTimer()
        self.enviroment_monitor.timeout.connect(self.EnviromentMonitor)
        self.enviroment_monitor.start(1000)
        
        #打印状态
        self.printing_status_monitor=QtCore.QTimer()
        self.printing_status_monitor.timeout.connect(self.printint_status)
        self.printing_status_monitor.start(50)
        
        #初始化打印机
        self.initPrinter()
        
        #初始化手动控制栏
        self.init_right()
        
        #绑定信号槽
        self.bindEvent()
    #窗口自适应  
    def resizeEvent(self,event):
        self.setToolbar()
    def initPrinter(self):
        self.printer=pronsole.pronsole()
        self.printer.connect_to_printer('/dev/cu.usbserial-14140',250000,dtr=None)
    def initshow(self):
        self.tabWidget = QtWidgets.QTabWidget(self)
        self.tabWidget.setTabPosition(QtWidgets.QTabWidget.South)
        self.tabWidget.setTabShape(QtWidgets.QTabWidget.Triangular)
        self.tabWidget.setElideMode(QtCore.Qt.ElideNone)
        self.tabWidget.setObjectName("tabWidget")
        self.opengl = GLWidget()
        self.opengl.setObjectName("opengl")
        self.tabWidget.addTab(self.opengl, "")
        #self.temperature = GraphicsLayoutWidget()
        self.temperature=graph(self.start_time)
        self.temperature.setObjectName("temperature")
        self.tabWidget.addTab(self.temperature, "")
        self.tabWidget.setTabText(0, "显示")
        self.tabWidget.setTabText(1, "温度曲线")
        self.tabWidget.setCurrentIndex(0)
        self.verticalLayout_3.addWidget(self.tabWidget)

    def initInject(self):
        #绘制坐标轴
        self.widget_2=Drawing(self)
        self.verticalLayout_10.addWidget(self.widget_2)
        #1号注射器
        self.inject_1=Inject(self)
        self.gridLayout.addWidget(self.inject_1, 0, 1, 1, 1)
        #2号注射器
        self.inject_2=Inject(self)
        self.gridLayout.addWidget(self.inject_2, 0, 2, 1, 1)
        #1号打印头按钮
        self.btn_inject_1=QtWidgets.QPushButton(self.widget_inject_1)
        self.btn_inject_1.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_1.png)}")
        #2号打印头按钮
        self.btn_inject_2=QtWidgets.QPushButton(self.widget_inject_2)
        self.btn_inject_2.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_2.png)}")
        #混合打印头按钮
        self.btn_inject_both=QtWidgets.QPushButton(self.widget_hunhe)
        self.btn_inject_both.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_both.png)}")
        self.setChannel()#软件启动后，默认选择通道1
    #初始化右侧手动工具栏
    def init_right(self):
        self.btn_inject1_takeout.setEnabled(False)
        self.btn_inject1_enject.setEnabled(False)
        self.tb_inject1_volume.setEnabled(False)
        self.btn_inject2_takeout.setEnabled(False)
        self.btn_inject2_enject.setEnabled(False)
        self.tb_inject2_volume.setEnabled(False)
        self.btn_peristaltic_1.setEnabled(False)
        self.btn_peristaltic_both.setEnabled(False)
        self.btn_peristaltic_2.setEnabled(False)
        self.rb_x.setEnabled(False)
        self.rb_y.setEnabled(False)
        self.rb_z.setEnabled(False)
        self.Move_relative_add.setEnabled(False)
        self.btn_zero.setEnabled(False)
        self.Move_relative_positive.setEnabled(False)
        self.btn_move_positive.setEnabled(False)
        self.btn_move_nagative.setEnabled(False)
        self.tb_move.setEnabled(False)
    def setChannel(self):
        if self.chan_1:
            self.btn_inject_1.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_1_choose.png)}")
            self.btn_inject_2.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_2.png)}")
            self.btn_inject_both.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_both.png)}")
            self.inject_1.drawpixmap=self.inject_1.image_inject_enabled
            self.inject_1.update()
            self.inject_2.drawpixmap=self.inject_2.image_inject_disabled
            self.inject_2.update()
        elif self.chan_2:
            self.btn_inject_1.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_1.png)}")
            self.btn_inject_2.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_2_choose.png)}")
            self.btn_inject_both.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_both.png)}")
            self.inject_1.drawpixmap=self.inject_1.image_inject_disabled
            self.inject_1.update()
            self.inject_2.drawpixmap=self.inject_2.image_inject_enabled
            self.inject_2.update()
        elif self.chan_both:
            self.btn_inject_1.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_1.png)}")
            self.btn_inject_2.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_2.png)}")
            self.btn_inject_both.setStyleSheet(r"QPushButton{background-image:url(resource/Inject/channel_both_choose.png)}")
            self.inject_1.drawpixmap=self.inject_1.image_inject_enabled
            self.inject_1.update()
            self.inject_2.drawpixmap=self.inject_2.image_inject_enabled
            self.inject_2.update()
    def setToolbar(self):
        #设置工具栏自适应
        width=self.widget_22.rect().width()
        height=self.widget_22.rect().height()
        h=height/2-20
        w=width/14
        self.tool_1.setGeometry(QtCore.QRect(w*2, h, 40, 40))
        self.tool_2.setGeometry(QtCore.QRect(w*5, h, 40, 40))
        self.tool_3.setGeometry(QtCore.QRect(w*6, h, 40, 40))
        self.tool_4.setGeometry(QtCore.QRect(w*10, h, 40, 40))
        self.tool_5.setGeometry(QtCore.QRect(w*11, h, 40, 40))
        self.tool_6.setGeometry(QtCore.QRect(w*12, h, 40, 40))
        self.tool_7.setGeometry(QtCore.QRect(w*13, h, 40, 40))
        self.tool_8.setGeometry(QtCore.QRect(w/2, h, 40, 40))
        #设置左侧btn_1自适应
        width_btn_inject_1=self.widget_inject_1.rect().width()
        height_btn_inject_1=self.widget_inject_1.rect().height()
        h_btn_inject_1=height_btn_inject_1/2-20
        w_btn_inject_1=width_btn_inject_1/2-20
        self.btn_inject_1.setGeometry(QtCore.QRect(w_btn_inject_1, h_btn_inject_1, 40, 40))
         #设置左侧btn_2自适应
        width_btn_inject_2=self.widget_inject_2.rect().width()
        height_btn_inject_2=self.widget_inject_2.rect().height()
        h_btn_inject_2=height_btn_inject_2/2-20
        w_btn_inject_2=width_btn_inject_2/2-20
        self.btn_inject_2.setGeometry(QtCore.QRect(w_btn_inject_2, h_btn_inject_2, 40, 40))
         #设置左侧btn_both自适应
        width_btn_inject_both=self.widget_hunhe.rect().width()
        height_btn_inject_both=self.widget_hunhe.rect().height()
        h_btn_inject_both=height_btn_inject_both/2-20
        w_btn_inject_both=width_btn_inject_both/2-20
        self.btn_inject_both.setGeometry(QtCore.QRect(w_btn_inject_both, h_btn_inject_both, 40, 40))
    def initToolBar(self):
        #导入G代码
        self.tool_1=QtWidgets.QPushButton(self.widget_22)
        self.tool_1.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/gcode_enabled.png)}")
        self.tool_1.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','导入G代码'))
        #打开灯光
        self.tool_2=QtWidgets.QPushButton(self.widget_22)
        self.tool_2.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/light_disabled.png)}")
        self.tool_2.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','打开灯光'))
        #参数设置
        self.tool_3=QtWidgets.QPushButton(self.widget_22)
        self.tool_3.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/settins_enabled.png)}")
        self.tool_3.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','参数设置'))
        #开始加工
        self.tool_4=QtWidgets.QPushButton(self.widget_22)
        self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
        self.tool_4.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','开始加工'))
        self.tool_4.setEnabled(False)
        #暂停加工
        self.tool_5=QtWidgets.QPushButton(self.widget_22)
        self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_disabled.png)}")
        self.tool_5.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','暂停加工'))
        self.tool_5.setEnabled(False)
        #恢复加工
        self.tool_6=QtWidgets.QPushButton(self.widget_22)
        self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_disabled.png)}")
        self.tool_6.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','恢复加工'))
        self.tool_6.setEnabled(False)
        #停止加工
        self.tool_7=QtWidgets.QPushButton(self.widget_22)
        self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_disabled.png)}")
        self.tool_7.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','停止加工'))
        self.tool_7.setEnabled(False)
        #注册
        self.tool_8=QtWidgets.QPushButton(self.widget_22)
        self.tool_8.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/register.png)}")
        self.tool_8.setToolTip(QtCore.QCoreApplication.translate('self.widget_22','注册'))
    def EnviromentMonitor(self):#循环，时间间隔为1s
        
        #设置加工时间
        self.label_process_time_hour.setText(str(datetime.timedelta(seconds=self.timesecond)))
        #设置一次开始加工图标
        if self.register and self.printer.fgcode and self.firstImport and self.register_time:
            self.tool_4.setEnabled(True)
            self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_enabled.png)}")
            self.firstImport=False
        #打印时间计算
        if self.printer.p.printing:
            self.timesecond=self.timesecond+1
        
            #设置x显示位置
        if self.printer.p.analyzer.current_x:
            self.widget_2.x=self.printer.p.analyzer.current_x
            #设置y显示位置
        if self.printer.p.analyzer.current_y:
            self.widget_2.y=self.printer.p.analyzer.current_y
            #设置z显示位置
        if self.printer.p.analyzer.current_z:
            self.widget_2.z=self.printer.p.analyzer.current_z
        self.widget_2.update()
            #设置总高度
        if self.printer.fgcode:
            if self.printer.fgcode.zmax:
                self.label_process_totallayer.setText("%.2f mm"%self.printer.fgcode.zmax)
            #设置总时间
            if self.printer.fgcode.duration:
                self.label_process_totaltime_hour.setText(str(self.printer.fgcode.duration))
        
        #设置基板温度
        if self.printer.status.bed_temp:
            self.label_temperature.setText("%d"%self.printer.status.bed_temp)
            self.temperature.data_analyse.append(self.printer.status.bed_temp)
            self.tick+=1
        else:
            self.label_temperature.setText('--')
        #self.tick+=1
        #self.temperature.data_analyse.append(np.random.normal())#测试用
        self.temperature.current_temp_plot()
        
        #设置注册状态
        if self.register and self.register_time:
            self.label_register.setText("已注册")
        elif self.register and not self.register_time:
            self.label_register.setText("已过期")
        else:
            self.label_register.setText("未注册")
        #设置完成百分比
        if self.printer.process:
            self.label_complete.setText("%.1f"%self.printer.process)
        print(self.printer.p.mainqueue)
    def bindEvent(self):
        self.tool_1.clicked.connect(self.importGcode)
        self.slider_layer.valueChanged.connect(self.sliderValueChange)
        self.tb_layer.editingFinished.connect(self.tbChange)
        self.tool_4.clicked.connect(self.startPrint)
        self.tool_5.clicked.connect(self.pausePrint)
        self.tool_6.clicked.connect(self.resumePrint)
        self.tool_7.clicked.connect(self.stopPrint)
        self.cb_munnal.clicked.connect(self.munnal)
        self.btn_inject_1.clicked.connect(self.channel_1_clicked)
        self.btn_inject_2.clicked.connect(self.channel_2_clicked)
        self.btn_inject_both.clicked.connect(self.channel_both_clicked)
        self.tool_3.clicked.connect(self.showSettings)
        self.btn_move_positive.clicked.connect(self.move_positive)
        self.btn_move_nagative.clicked.connect(self.move_nagative)
        self.Move_relative_add.pressed.connect(self.startmove_positive)
        self.Move_relative_add.released.connect(self.stopmove_positive)
        self.Move_relative_positive.pressed.connect(self.startmove_nagative)
        self.Move_relative_positive.released.connect(self.stopmove_nagative)
        self.btn_zero.clicked.connect(self.zero)
        self.tool_3.clicked.connect(self.paraSetting)
    def paraSetting(self):
        print(self.printer.p.bed_temp_target)
        bed_temperature=str(self.printer.p.bed_temp_target)
        speed_xy=str(self.printer.settings.xy_feedrate)
        speed_z=str(self.printer.settings.z_feedrate)
        speed_inject=str(0.5)
        self.wid=ParaDialog()
        self.wid.bed_temperature.setText(bed_temperature)
        self.wid.speed_xy.setText(speed_xy)
        self.wid.speed_z.setText(speed_z)
        self.wid.speed_inject.setText(speed_inject)
        if self.wid.exec_():
            if self.wid.tb_bedtemp.text():
                try:
                    tmp=float(self.wid.tb_bedtemp.text())
                except:
                    tmp=float(bed_temperature)
                if tmp<0:
                    tmp=0
                if tmp>300:
                    tmp=300
                self.printer.p.bed_temp_target=tmp
            if self.wid.tb_xyspeed.text():
                try:
                    tmp=float(self.wid.tb_xyspeed.text())
                except:
                    tmp=float(speed_xy)
                if tmp<0:
                    tmp=0
                if tmp>5000:
                    tmp=5000
                self.printer.settings._set('xy_feedrate',tmp)
            if self.wid.tb_zspeed.text():
                try:
                    tmp=float(self.wid.tb_zspeed.text())
                except:
                    tmp=float(speed_z)
                if tmp<0:
                    tmp=0
                if tmp>5000:
                    tmp=5000
                self.printer.settings._set('z_feedrate',tmp)
            if self.wid.tb_injectspeed.text():
                pass
    def zero(self):
        if self.rb_x.isChecked():
            axis='x'
        elif self.rb_y.isChecked():
            axis='y'
        elif self.rb_z.isChecked():
            axis='z'
        self.printer.do_home(axis)
        self.widget_2.x=0
        self.widget_2.y=0
        self.widget_2.z=0
    def startmove_positive(self):
        self.startTimer=QtCore.QTimer()
        self.startTimer.timeout.connect(self.move_positive_no_wait)
        if self.rb_x.isChecked() or self.rb_y.isChecked():
            self.startTimer.start(12)
        elif self.rb_z.isChecked():
            self.startTimer.start(163)
        
    def stopmove_positive(self):
        self.startTimer.stop()
    def move_positive_no_wait(self):
        self.moveAxis(True,False)
    def startmove_nagative(self):
        self.startTimer=QtCore.QTimer()
        self.startTimer.timeout.connect(self.move_nagative_no_wait)
        if self.rb_x.isChecked() or self.rb_y.isChecked():
            self.startTimer.start(12)
        elif self.rb_z.isChecked():
            self.startTimer.start(163)
    def stopmove_nagative(self):
        self.startTimer.stop()
    def move_nagative_no_wait(self):
        self.moveAxis(False,False)
    def move_positive(self):
        self.moveAxis(True)
    def move_nagative(self):
        self.moveAxis(False)
    def moveAxis(self,positive,length=True):
        if self.rb_x.isChecked():
            axis='x'
        elif self.rb_y.isChecked():
            axis='y'
        elif self.rb_z.isChecked():
            axis='z'
        if length:
            try:
                print(self.tb_move.text())
                step=float(self.tb_move.text())
            except:
                step=0
        else:
            step=0.3
        if positive:
            step=abs(step)
        else:
            step=-abs(step)    
        command=axis+" "+str(step)
        self.printer.do_move(command)  
    #弹出参数设置界面
    def showSettings(self):
        pass
    def channel_1_clicked(self):
        if self.chan_1:
            self.chan_1=False
        else:
            self.chan_1=True
            self.chan_2=False
            self.chan_both=False
        self.setChannel()
    def channel_2_clicked(self):
        if self.chan_2:
            self.chan_2=False
        else:
            self.chan_2=True
            self.chan_1=False
            self.chan_both=False
        self.setChannel()
    def channel_both_clicked(self):
        if self.chan_both:
            self.chan_both=False
        else:
            self.chan_1=False
            self.chan_2=False
            self.chan_both=True
        self.setChannel()
    def munnal(self):
        if self.cb_munnal.isChecked():
            self.btn_inject1_takeout.setEnabled(True)
            self.btn_inject1_enject.setEnabled(True)
            self.tb_inject1_volume.setEnabled(True)
            self.btn_inject2_takeout.setEnabled(True)
            self.btn_inject2_enject.setEnabled(True)
            self.tb_inject2_volume.setEnabled(True)
            self.btn_peristaltic_1.setEnabled(True)
            self.btn_peristaltic_both.setEnabled(True)
            self.btn_peristaltic_2.setEnabled(True)
            self.rb_x.setEnabled(True)
            self.rb_y.setEnabled(True)
            self.rb_z.setEnabled(True)
            self.Move_relative_add.setEnabled(True)
            self.btn_zero.setEnabled(True)
            self.Move_relative_positive.setEnabled(True)
            self.btn_move_positive.setEnabled(True)
            self.btn_move_nagative.setEnabled(True)
            self.tb_move.setEnabled(True)
        else:
            self.btn_inject1_takeout.setEnabled(False)
            self.btn_inject1_enject.setEnabled(False)
            self.tb_inject1_volume.setEnabled(False)
            self.btn_inject2_takeout.setEnabled(False)
            self.btn_inject2_enject.setEnabled(False)
            self.tb_inject2_volume.setEnabled(False)
            self.btn_peristaltic_1.setEnabled(False)
            self.btn_peristaltic_both.setEnabled(False)
            self.btn_peristaltic_2.setEnabled(False)
            self.rb_x.setEnabled(False)
            self.rb_y.setEnabled(False)
            self.rb_z.setEnabled(False)
            self.Move_relative_add.setEnabled(False)
            self.btn_zero.setEnabled(False)
            self.Move_relative_positive.setEnabled(False)
            self.btn_move_positive.setEnabled(False)
            self.btn_move_nagative.setEnabled(False)
            self.tb_move.setEnabled(False)
    def printint_status(self):
        #设置当前状态
        if self.printer.p.printing:
            self.label_status.setText("正在打印")
            if self.printer.fgcode.has_index(self.printer.p.queueindex):
                layer,line=self.printer.fgcode.idxs(self.printer.p.queueindex)
                self.slider_layer.setValue(layer-1)
            #设置加工高度
            self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
            self.tool_4.setEnabled(False)
            self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
            self.tool_5.setEnabled(True)
            self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_enabled.png)}")
            self.tool_6.setEnabled(False)
            self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_disabled.png)}")
            self.tool_7.setEnabled(True)
            self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_enabled.png)}")
            self.cb_munnal.setChecked(False)
            self.munnal()
            self.cb_munnal.setEnabled(False)
            
        elif self.printer.paused:
            self.label_status.setText("已暂停")
            self.tool_4.setEnabled(False)
            self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
            self.tool_5.setEnabled(False)
            self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_disabled.png)}")
            self.tool_6.setEnabled(True)
            self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_enabled.png)}")
            self.tool_7.setEnabled(True)
            self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_enabled.png)}")
            self.cb_munnal.setEnabled(True)
            
            
        elif self.finish:
            self.label_status.setText("已停止")
    def startPrint(self):
        '''self.tool_4.setEnabled(False)
        self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
        self.tool_5.setEnabled(True)
        self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_enabled.png)}")
        self.tool_6.setEnabled(False)
        self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_disabled.png)}")
        self.tool_7.setEnabled(True)
        self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_enabled.png)}")
        self.cb_munnal.setChecked(False)
        self.munnal()
        self.cb_munnal.setEnabled(False)'''
        self.temperature.addPoint('start',self.tick)
        self.temperature.analyse_plot()
        self.timesecond=0
        self.printer.do_print(1)
        
    def pausePrint(self):
        '''self.tool_4.setEnabled(False)
        self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
        self.tool_5.setEnabled(False)
        self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_disabled.png)}")
        self.tool_6.setEnabled(True)
        self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_enabled.png)}")
        self.tool_7.setEnabled(True)
        self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_enabled.png)}")
        self.cb_munnal.setEnabled(True)
        
        self.temperature.addPoint('pause',self.tick)
        self.temperature.analyse_plot()'''
        self.temperature.addPoint('pause',self.tick)
        self.temperature.analyse_plot()
        self.printer.pause()
    def resumePrint(self):
        '''self.tool_4.setEnabled(False)
        self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
        self.tool_5.setEnabled(True)
        self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_enabled.png)}")
        self.tool_6.setEnabled(False)
        self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_disabled.png)}")
        self.tool_7.setEnabled(True)
        self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_enabled.png)}")
        self.cb_munnal.setChecked(False)
        self.munnal()
        self.cb_munnal.setEnabled(False)'''
        self.printer.do_resume(1)
        self.temperature.addPoint('resume',self.tick)
        self.temperature.analyse_plot()
    def stopPrint(self):
        attention=QtWidgets.QMessageBox()
        reply=attention.question(self,"是否取消打印？","取消打印后无法恢复，请确认是否取消打印！",
                                             QtWidgets.QMessageBox.Yes|QtWidgets.QMessageBox.No,QtWidgets.QMessageBox.Yes)
        if reply==QtWidgets.QMessageBox.Yes:
            self.tool_4.setEnabled(True)
            self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_enabled.png)}")
            self.tool_5.setEnabled(False)
            self.tool_5.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/pause_disabled.png)}")
            self.tool_6.setEnabled(False)
            self.tool_6.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/resume_disabled.png)}")
            self.tool_7.setEnabled(False)
            self.tool_7.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/stop_disabled.png)}")
            self.cb_munnal.setEnabled(True)
            self.printer.pause()
            self.temperature.addPoint('stop',self.tick)
            self.temperature.analyse_plot()
    def tbChange(self):
        slider_value=self.slider_layer.value()
        slider_max=self.slider_layer.maximum()
        try:
            value=int(self.tb_layer.text())
        except:
            value=slider_value
        if value<1:
            value=1
        if value>slider_max:
            value=slider_max
        self.slider_layer.setValue(value)
        self.tb_layer.setText(str(value))
    def sliderValueChange(self):
        self.tb_layer.setText(str(self.slider_layer.value()))
        self.opengl.showlayer=self.slider_layer.value()-1
        self.opengl.update()
    
    def importGcode(self):
        dlg=QtWidgets.QFileDialog()
        f=dlg.getOpenFileName(self,'Open File','.','GCode file (*.gcode)')
        if f[0]:
            self.printer.do_load(f[0])
            self.slider_layer.setMaximum(len(self.printer.all_layers_for_opengl))
            self.opengl.initdata(self.printer.all_layers_for_opengl)
            self.opengl.update()
            for line in self.printer.fgcode.all_layers[1]:
                if line.command=='M190':
                    s=line.raw.split()[-1]
                    s=s.replace('S','')
                    self.printer.p.bed_temp_target=float(s)
app=QtWidgets.QApplication(sys.argv)
window=myform()
window.show()
app.exec_()
sys.exit()
# Out:
#  PC> None
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in startPrint(self)
#     511         self.munnal()
#     512         self.cb_munnal.setEnabled(False)'''
# --> 513         self.temperature.addPoint('start',self.tick)
#     514         self.temperature.analyse_plot()
#     515         self.timesecond=0
#
# ~/Documents/Pythonfile/Multi/Multi_solvent-master/form/widget/Graph.py in addPoint(self, command, tick)
#      36     def addPoint(self,command,tick):
#      37         if command=="start":
# ---> 38             self.start_point.append([tick-1,self.data_analyse[tick-1]])
#      39         elif command=='pause':
#      40             self.pause_point.append([tick-1,self.data_analyse[tick-1]])
#
# IndexError: list index out of range
# None
# None
# None
# None
# 当前执行： G28
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 Z15 F100
# 当前执行： M107
# 当前执行： G90
# 当前执行： M82
# 当前执行： M190 S20.0
# 当前执行： M104 T0 S19
# 当前执行： G92 E0
# 当前执行： M109 T0 S19
# 当前执行： M107
# 当前执行： G0 F6000 X8.921 Y7.449 Z0.300
# 当前执行： G1 F2100 X48.521 Y7.449 E1.97565
# 加工进度： 3.2
# 加工进度： 3.2
# 当前执行： G1 X48.521 Y47.049 E3.95130
# 加工进度： 3.3
# 加工进度： 3.3
# 当前执行： G1 X8.921 Y47.049 E5.92696
# 加工进度： 3.5
# 加工进度： 3.5
# 当前执行： G1 X8.921 Y7.449 E7.90261
# 加工进度： 3.7
# 加工进度： 3.7
# 当前执行： G0 F6000 X9.321 Y7.849
# 当前执行： G1 F2100 X48.121 Y7.849 E9.83835
# 加工进度： 4.0
# 加工进度： 4.0
# 当前执行： G1 X48.121 Y46.649 E11.77409
# 加工进度： 4.2
# 加工进度： 4.2
# 当前执行： G1 X9.321 Y46.649 E13.70983
# 加工进度： 4.3
# 加工进度： 4.3
# 当前执行： G1 X9.321 Y7.849 E15.64557
# 加工进度： 4.5
# 加工进度： 4.5
# 当前执行： G0 F6000 X9.721 Y8.249
# 当前执行： G1 F2100 X47.721 Y8.249 E17.54140
# 加工进度： 4.9
# 加工进度： 4.9
# 当前执行： G1 X47.721 Y46.249 E19.43722
# 加工进度： 5.0
# 加工进度： 5.0
# 当前执行： G1 X9.721 Y46.249 E21.33305
# 加工进度： 5.2
# 加工进度： 5.2
# 当前执行： G1 X9.721 Y8.249 E23.22888
# 加工进度： 5.4
# 加工进度： 5.4
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X10.121 Y8.649
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X47.321 Y8.649 E25.08479
# 加工进度： 5.7
# 加工进度： 5.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X47.321 Y45.849 E26.94071
# 加工进度： 5.9
# 加工进度： 5.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.121 Y45.849 E28.79662
# 加工进度： 6.0
# 加工进度： 6.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.121 Y8.649 E30.65254
# 加工进度： 6.2
# 加工进度： 6.2
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X10.521 Y9.049
# 当前执行： G1 F2100 X46.921 Y9.049 E32.46854
# 加工进度： 6.5
# 加工进度： 6.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X46.921 Y45.449 E34.28455
# 加工进度： 6.7
# 加工进度： 6.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.521 Y45.449 E36.10055
# 加工进度： 6.9
# 加工进度： 6.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.521 Y9.049 E37.91655
# 加工进度： 7.1
# 加工进度： 7.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X10.921 Y9.449
# 当前执行： G1 F2100 X46.521 Y9.449 E39.69265
# 加工进度： 7.4
# 加工进度： 7.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X46.521 Y45.049 E41.46874
# 加工进度： 7.6
# 加工进度： 7.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.921 Y45.049 E43.24483
# 加工进度： 7.7
# 加工进度： 7.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X10.921 Y9.449 E45.02092
# 加工进度： 7.9
# 加工进度： 7.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X11.321 Y9.849
# 当前执行： G1 F2100 X46.121 Y9.849 E46.75710
# 加工进度： 8.2
# 加工进度： 8.2
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X46.121 Y44.649 E48.49328
# 加工进度： 8.4
# 加工进度： 8.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X11.321 Y44.649 E50.22946
# 加工进度： 8.6
# 加工进度： 8.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X11.321 Y9.849 E51.96563
# 加工进度： 8.7
# 加工进度： 8.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X11.721 Y10.249
# 当前执行： G1 F2100 X45.721 Y10.249 E53.66190
# 加工进度： 9.1
# 加工进度： 9.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X45.721 Y44.249 E55.35817
# 加工进度： 9.3
# 加工进度： 9.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X11.721 Y44.249 E57.05444
# 加工进度： 9.4
# 加工进度： 9.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X11.721 Y10.249 E58.75070
# 加工进度： 9.6
# 加工进度： 9.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X12.121 Y10.649
# 当前执行： G1 F2100 X45.321 Y10.649 E60.40706
# 加工进度： 9.9
# 加工进度： 9.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X45.321 Y43.849 E62.06341
# 加工进度： 10.1
# 加工进度： 10.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.121 Y43.849 E63.71977
# 加工进度： 10.3
# 加工进度： 10.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.121 Y10.649 E65.37612
# 加工进度： 10.4
# 加工进度： 10.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X12.521 Y11.049
# 当前执行： G1 F2100 X44.921 Y11.049 E66.99256
# 加工进度： 10.8
# 加工进度： 10.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X44.921 Y43.449 E68.60901
# 加工进度： 10.9
# 加工进度： 10.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.521 Y43.449 E70.22545
# 加工进度： 11.1
# 加工进度： 11.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.521 Y11.049 E71.84189
# 加工进度： 11.3
# 加工进度： 11.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X12.921 Y11.449
# 当前执行： G1 F2100 X44.521 Y11.449 E73.41842
# 加工进度： 11.6
# 加工进度： 11.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X44.521 Y43.049 E74.99495
# 加工进度： 11.8
# 加工进度： 11.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.921 Y43.049 E76.57148
# 加工进度： 12.0
# 加工进度： 12.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X12.921 Y11.449 E78.14801
# 加工进度： 12.1
# 加工进度： 12.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X13.321 Y11.849
# 当前执行： G1 F2100 X44.121 Y11.849 E79.68463
# 加工进度： 12.5
# 加工进度： 12.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X44.121 Y42.649 E81.22125
# 加工进度： 12.6
# 加工进度： 12.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X13.321 Y42.649 E82.75787
# 加工进度： 12.8
# 加工进度： 12.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X13.321 Y11.849 E84.29449
# 加工进度： 13.0
# 加工进度： 13.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X13.721 Y12.249
# 当前执行： G1 F2100 X43.721 Y12.249 E85.79119
# 加工进度： 13.3
# 加工进度： 13.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X43.721 Y42.249 E87.28790
# 加工进度： 13.5
# 加工进度： 13.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X13.721 Y42.249 E88.78460
# 加工进度： 13.7
# 加工进度： 13.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X13.721 Y12.249 E90.28131
# 加工进度： 13.8
# 加工进度： 13.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X14.121 Y12.649
# 当前执行： G1 F2100 X43.321 Y12.649 E91.73810
# 加工进度： 14.2
# 加工进度： 14.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X43.321 Y41.849 E93.19490
# 加工进度： 14.3
# 加工进度： 14.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.121 Y41.849 E94.65169
# 加工进度： 14.5
# 加工进度： 14.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.121 Y12.649 E96.10849
# 加工进度： 14.7
# 加工进度： 14.7
# 当前执行： G0 F6000 X14.521 Y13.049
# 当前执行： G1 F2100 X42.921 Y13.049 E97.52537
# 加工进度： 15.0
# 加工进度： 15.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X42.921 Y41.449 E98.94225
# 加工进度： 15.2
# 加工进度： 15.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.521 Y41.449 E100.35913
# 加工进度： 15.3
# 加工进度： 15.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.521 Y13.049 E101.77601
# 加工进度： 15.5
# 加工进度： 15.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X14.921 Y13.449
# 当前执行： G1 F2100 X42.521 Y13.449 E103.15298
# 加工进度： 15.9
# 加工进度： 15.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X42.521 Y41.049 E104.52995
# 加工进度： 16.0
# 加工进度： 16.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.921 Y41.049 E105.90692
# 加工进度： 16.2
# 加工进度： 16.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X14.921 Y13.449 E107.28389
# 加工进度： 16.4
# 加工进度： 16.4
# 当前执行： G0 F6000 X15.321 Y13.849
# 当前执行： G1 F2100 X42.121 Y13.849 E108.62095
# <gcoder.GCode object at 0x14ef4d828>
# 加工进度： 16.7
# 加工进度： 16.7
# 当前执行： G1 X42.121 Y40.649 E109.95801
# 加工进度： 16.9
# 加工进度： 16.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X15.321 Y40.649 E111.29506
# 加工进度： 17.0
# 加工进度： 17.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X15.321 Y13.849 E112.63212
# 加工进度： 17.2
# 加工进度： 17.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X15.721 Y14.249
# 当前执行： G1 F2100 X41.721 Y14.249 E113.92927
# 加工进度： 17.5
# 加工进度： 17.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X41.721 Y40.249 E115.22641
# 加工进度： 17.7
# 加工进度： 17.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X15.721 Y40.249 E116.52356
# 加工进度： 17.9
# 加工进度： 17.9
# 当前执行： G1 X15.721 Y14.249 E117.82070
# 加工进度： 18.1
# 加工进度： 18.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X16.121 Y14.649
# 当前执行： G1 F2100 X41.321 Y14.649 E119.07794
# 加工进度： 18.4
# 加工进度： 18.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X41.321 Y39.849 E120.33517
# 加工进度： 18.6
# 加工进度： 18.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.121 Y39.849 E121.59240
# 加工进度： 18.7
# 加工进度： 18.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.121 Y14.649 E122.84963
# 加工进度： 18.9
# 加工进度： 18.9
# 当前执行： G0 F6000 X16.521 Y15.049
# 当前执行： G1 F2100 X40.921 Y15.049 E124.06696
# 加工进度： 19.2
# 加工进度： 19.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X40.921 Y39.449 E125.28428
# 加工进度： 19.4
# 加工进度： 19.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.521 Y39.449 E126.50160
# 加工进度： 19.6
# 加工进度： 19.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.521 Y15.049 E127.71892
# 加工进度： 19.7
# 加工进度： 19.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X16.921 Y15.449
# 当前执行： G1 F2100 X40.521 Y15.449 E128.89633
# 加工进度： 20.1
# 加工进度： 20.1
# 当前执行： G1 X40.521 Y39.049 E130.07374
# 加工进度： 20.3
# 加工进度： 20.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.921 Y39.049 E131.25114
# 加工进度： 20.4
# 加工进度： 20.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X16.921 Y15.449 E132.42855
# 加工进度： 20.6
# 加工进度： 20.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X17.321 Y15.849
# 当前执行： G1 F2100 X40.121 Y15.849 E133.56605
# 加工进度： 20.9
# 加工进度： 20.9
# 当前执行： G1 X40.121 Y38.649 E134.70355
# 加工进度： 21.1
# 加工进度： 21.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X17.321 Y38.649 E135.84104
# 加工进度： 21.3
# 加工进度： 21.3
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X17.321 Y15.849 E136.97854
# 加工进度： 21.4
# 加工进度： 21.4
# 当前执行： G0 F6000 X17.721 Y16.249
# 当前执行： G1 F2100 X39.721 Y16.249 E138.07612
# 加工进度： 21.8
# 加工进度： 21.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X39.721 Y38.249 E139.17371
# 加工进度： 21.9
# 加工进度： 21.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X17.721 Y38.249 E140.27129
# 加工进度： 22.1
# 加工进度： 22.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X17.721 Y16.249 E141.36888
# 加工进度： 22.3
# 加工进度： 22.3
# 当前执行： G0 F6000 X18.121 Y16.649
# 当前执行： G1 F2100 X39.321 Y16.649 E142.42655
# 加工进度： 22.6
# 加工进度： 22.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X39.321 Y37.849 E143.48422
# 加工进度： 22.8
# 加工进度： 22.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X18.121 Y37.849 E144.54189
# 加工进度： 23.0
# 加工进度： 23.0
# 当前执行： G1 X18.121 Y16.649 E145.59957
# 加工进度： 23.1
# 加工进度： 23.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X18.521 Y17.049
# 当前执行： G1 F2100 X38.921 Y17.049 E146.61733
# 加工进度： 23.5
# 加工进度： 23.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X38.921 Y37.449 E147.63509
# 加工进度： 23.6
# 加工进度： 23.6
# 当前执行： G1 X18.521 Y37.449 E148.65285
# 加工进度： 23.8
# 加工进度： 23.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X18.521 Y17.049 E149.67061
# 加工进度： 24.0
# 加工进度： 24.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.321 Y17.849
# 当前执行： G1 F2100 X38.121 Y17.849 E150.60854
# 加工进度： 24.5
# 加工进度： 24.5
# 当前执行： G1 X38.121 Y36.649 E151.54648
# 加工进度： 24.7
# 加工进度： 24.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X19.321 Y36.649 E152.48442
# 加工进度： 24.8
# 加工进度： 24.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X19.321 Y17.849 E153.42235
# 加工进度： 25.0
# 加工进度： 25.0
# 当前执行： G0 F6000 X18.921 Y17.449
# 当前执行： G1 F2100 X38.521 Y17.449 E154.40020
# 加工进度： 25.5
# 加工进度： 25.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X38.521 Y37.049 E155.37805
# 加工进度： 25.7
# 加工进度： 25.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 X18.921 Y37.049 E156.35589
# 加工进度： 25.8
# 加工进度： 25.8
# 当前执行： G1 X18.921 Y17.449 E157.33374
# 加工进度： 26.0
# 加工进度： 26.0
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y18.046
# 当前执行： G1 F2100 X37.922 Y36.508 E158.63634
# 加工进度： 26.5
# 加工进度： 26.5
# 当前执行： G0 F6000 X37.980 Y36.000
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.969 Y17.989 E159.90711
# 加工进度： 26.9
# 加工进度： 26.9
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y18.611
# 当前执行： G1 F2100 X37.357 Y36.508 E161.16984
# 加工进度： 27.2
# 加工进度： 27.2
# 当前执行： G0 F6000 X36.791 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y19.177 E162.39264
# 加工进度： 27.5
# 加工进度： 27.5
# 当前执行： G0 F6000 X19.460 Y19.743
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X36.225 Y36.508 E163.57550
# 加工进度： 27.9
# 加工进度： 27.9
# 当前执行： G0 F6000 X35.660 Y36.508
# 当前执行： G1 F2100 X19.460 Y20.308 E164.71849
# 加工进度： 28.2
# 加工进度： 28.2
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y20.874
# 当前执行： G1 F2100 X35.094 Y36.508 E165.82156
# 加工进度： 28.5
# 加工进度： 28.5
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X34.528 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y21.440 E166.88469
# 加工进度： 28.9
# 加工进度： 28.9
# 当前执行： G0 F6000 X19.460 Y22.005
# 当前执行： G1 F2100 X33.963 Y36.508 E167.90795
# 加工进度： 29.2
# 加工进度： 29.2
# 当前执行： G0 F6000 X33.397 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y22.571 E168.89128
# 加工进度： 29.6
# 加工进度： 29.6
# 当前执行： G0 F6000 X19.460 Y23.137
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X32.831 Y36.508 E169.83468
# 加工进度： 29.9
# 加工进度： 29.9
# 当前执行： G0 F6000 X32.265 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y23.702 E170.73818
# 加工进度： 30.2
# 加工进度： 30.2
# 当前执行： G0 F6000 X19.460 Y24.268
# 当前执行： G1 F2100 X31.700 Y36.508 E171.60177
# 加工进度： 30.6
# 加工进度： 30.6
# 当前执行： G0 F6000 X31.134 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y24.834 E172.42544
# 加工进度： 30.9
# 加工进度： 30.9
# 当前执行： G0 F6000 X19.460 Y25.399
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X30.568 Y36.508 E173.20920
# 加工进度： 31.3
# 加工进度： 31.3
# 当前执行： G0 F6000 X30.003 Y36.508
# 当前执行： G1 F2100 X19.460 Y25.965 E173.95307
# 加工进度： 31.6
# 加工进度： 31.6
# 当前执行： G0 F6000 X19.460 Y26.531
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X29.437 Y36.508 E174.65700
# 加工进度： 31.9
# 加工进度： 31.9
# 当前执行： G0 F6000 X28.871 Y36.508
# 当前执行： G1 F2100 X19.460 Y27.097 E175.32100
# 加工进度： 32.3
# 加工进度： 32.3
# 当前执行： G0 F6000 X19.460 Y27.662
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X28.305 Y36.507 E175.94506
# 加工进度： 32.6
# 加工进度： 32.6
# 当前执行： G0 F6000 X27.739 Y36.507
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y28.228 E176.52919
# 加工进度： 32.9
# 加工进度： 32.9
# 当前执行： G0 F6000 X19.460 Y28.794
# 当前执行： G1 F2100 X27.174 Y36.507 E177.07342
# 加工进度： 33.3
# 加工进度： 33.3
# 当前执行： G0 F6000 X26.608 Y36.507
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y29.359 E177.57775
# 加工进度： 33.6
# 加工进度： 33.6
# 当前执行： G0 F6000 X19.460 Y29.925
# 当前执行： G1 F2100 X26.042 Y36.507 E178.04214
# 加工进度： 34.0
# 加工进度： 34.0
# 当前执行： G0 F6000 X25.477 Y36.507
# 当前执行： G1 F2100 X19.460 Y30.491 E178.46664
# 加工进度： 34.3
# 加工进度： 34.3
# 当前执行： G0 F6000 X19.460 Y31.056
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X24.911 Y36.507 E178.85124
# 加工进度： 34.6
# 加工进度： 34.6
# 当前执行： G0 F6000 X24.345 Y36.507
# 当前执行： G1 F2100 X19.460 Y31.622 E179.19590
# 加工进度： 35.0
# 加工进度： 35.0
# 当前执行： G0 F6000 X19.460 Y32.188
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X23.780 Y36.507 E179.50066
# 加工进度： 35.3
# 加工进度： 35.3
# 当前执行： G0 F6000 X23.214 Y36.507
# 当前执行： G1 F2100 X19.460 Y32.753 E179.76553
# 加工进度： 35.7
# 加工进度： 35.7
# 当前执行： G0 F6000 X19.460 Y33.319
# 当前执行： G1 F2100 X22.648 Y36.507 E179.99046
# 加工进度： 36.0
# 加工进度： 36.0
# 当前执行： G0 F6000 X22.082 Y36.507
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X19.460 Y33.885 E180.17545
# 加工进度： 36.3
# 加工进度： 36.3
# 当前执行： G0 F6000 X19.460 Y34.450
# 当前执行： G1 F2100 X21.517 Y36.507 E180.32059
# 加工进度： 36.7
# 加工进度： 36.7
# 当前执行： G0 F6000 X20.951 Y36.507
# 当前执行： G1 F2100 X19.460 Y35.016 E180.42578
# 加工进度： 37.0
# 加工进度： 37.0
# 当前执行： G0 F6000 X19.460 Y35.582
# 当前执行： G1 F2100 X20.385 Y36.507 E180.49105
# 加工进度： 37.3
# 加工进度： 37.3
# 当前执行： G0 F6000 X37.980 Y35.434
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X20.535 Y17.989 E181.72189
# 加工进度： 37.7
# 加工进度： 37.7
# 当前执行： G0 F6000 X21.100 Y17.989
# 当前执行： G1 F2100 X37.980 Y34.868 E182.91283
# 加工进度： 38.0
# 加工进度： 38.0
# 当前执行： G0 F6000 X37.980 Y34.303
# 当前执行： G1 F2100 X21.666 Y17.989 E184.06387
# 加工进度： 38.4
# 加工进度： 38.4
# 当前执行： G0 F6000 X22.232 Y17.989
# 当前执行： G1 F2100 X37.980 Y33.737 E185.17497
# 加工进度： 38.7
# 加工进度： 38.7
# 当前执行： G0 F6000 X37.980 Y33.171
# 当前执行： G1 F2100 X22.797 Y17.989 E186.24618
# 加工进度： 39.0
# 加工进度： 39.0
# 当前执行： G0 F6000 X23.363 Y17.989
# 当前执行： G1 F2100 X37.980 Y32.606 E187.27749
# 加工进度： 39.4
# 加工进度： 39.4
# 当前执行： G0 F6000 X37.980 Y32.040
# 当前执行： G1 F2100 X23.929 Y17.989 E188.26886
# 加工进度： 39.7
# 加工进度： 39.7
# 当前执行： G0 F6000 X24.494 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y31.474 E189.22034
# 加工进度： 40.1
# 加工进度： 40.1
# 当前执行： G0 F6000 X37.980 Y30.909
# 当前执行： G1 F2100 X25.060 Y17.989 E190.13191
# 加工进度： 40.4
# 加工进度： 40.4
# 当前执行： G0 F6000 X25.626 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y30.343 E191.00356
# 加工进度： 40.7
# 加工进度： 40.7
# 当前执行： G0 F6000 X37.980 Y29.777
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X26.191 Y17.989 E191.83530
# 加工进度： 41.1
# 加工进度： 41.1
# 当前执行： G0 F6000 X26.757 Y17.989
# 当前执行： G1 F2100 X37.980 Y29.211 E192.62711
# 加工进度： 41.4
# 加工进度： 41.4
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X37.980 Y28.646
# 当前执行： G1 F2100 X27.323 Y17.989 E193.37902
# 加工进度： 41.7
# 加工进度： 41.7
# 当前执行： G0 F6000 X27.888 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y28.080 E194.09103
# 加工进度： 42.1
# 加工进度： 42.1
# 当前执行： G0 F6000 X37.980 Y27.514
# 当前执行： G1 F2100 X28.454 Y17.989 E194.76310
# 加工进度： 42.4
# 加工进度： 42.4
# 当前执行： G0 F6000 X29.020 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y26.949 E195.39528
# 加工进度： 42.8
# 加工进度： 42.8
# 当前执行： G0 F6000 X37.980 Y26.383
# 当前执行： G1 F2100 X29.586 Y17.989 E195.98752
# 加工进度： 43.1
# 加工进度： 43.1
# 当前执行： G0 F6000 X30.151 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y25.817 E196.53986
# 加工进度： 43.4
# 加工进度： 43.4
# 当前执行： G0 F6000 X37.980 Y25.252
# 当前执行： G1 F2100 X30.717 Y17.989 E197.05231
# 加工进度： 43.8
# 加工进度： 43.8
# 当前执行： G0 F6000 X31.283 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y24.686 E197.52482
# 加工进度： 44.1
# 加工进度： 44.1
# 当前执行： G0 F6000 X37.980 Y24.120
# 当前执行： G1 F2100 X31.848 Y17.989 E197.95743
# 加工进度： 44.5
# 加工进度： 44.5
# 当前执行： G0 F6000 X32.414 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y23.555 E198.35014
# 加工进度： 44.8
# 加工进度： 44.8
# 当前执行： G0 F6000 X37.980 Y22.989
# 当前执行： G1 F2100 X32.980 Y17.989 E198.70291
# 加工进度： 45.1
# 加工进度： 45.1
# 当前执行： G0 F6000 X33.545 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.980 Y22.423 E199.01579
# 加工进度： 45.5
# 加工进度： 45.5
# 当前执行： G0 F6000 X37.980 Y21.858
# 当前执行： G1 F2100 X34.111 Y17.989 E199.28877
# 加工进度： 45.8
# 加工进度： 45.8
# 当前执行： G0 F6000 X34.677 Y17.989
# 当前执行： G1 F2100 X37.980 Y21.292 E199.52182
# 加工进度： 46.1
# 加工进度： 46.1
# 当前执行： G0 F6000 X37.980 Y20.726
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X35.242 Y17.989 E199.71496
# 加工进度： 46.5
# 加工进度： 46.5
# 当前执行： G0 F6000 X35.808 Y17.989
# 当前执行： G1 F2100 X37.980 Y20.161 E199.86821
# 加工进度： 46.8
# 加工进度： 46.8
# 当前执行： G0 F6000 X37.980 Y19.595
# 当前执行： G1 F2100 X36.374 Y17.989 E199.98152
# 加工进度： 47.2
# 加工进度： 47.2
# 当前执行： G0 F6000 X36.939 Y17.989
# 当前执行： G1 F2100 X37.980 Y19.029 E200.05493
# 加工进度： 47.5
# 加工进度： 47.5
# 当前执行： G0 F6000 X37.980 Y18.463
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2100 X37.505 Y17.989 E200.08841
# 加工进度： 47.8
# 加工进度： 47.8
# 当前执行： G0 F6000 X19.460 Y36.148
# 当前执行： G1 F2100 X19.820 Y36.507 E200.11378
# 加工进度： 48.2
# 加工进度： 48.2
# 当前执行： M106 S127
# 当前执行： G0 F6000 X19.321 Y36.649 Z0.600
# 当前执行： G1 F2160 X19.321 Y17.849 E201.05171
# 加工进度： 49.0
# 加工进度： 49.0
# 当前执行： G1 X38.121 Y17.849 E201.98965
# 加工进度： 49.2
# 加工进度： 49.2
# 当前执行： G1 X38.121 Y36.649 E202.92758
# 加工进度： 49.4
# 加工进度： 49.4
# 当前执行： G1 X19.321 Y36.649 E203.86552
# 加工进度： 49.5
# 加工进度： 49.5
# 当前执行： G0 F6000 X18.921 Y37.049
# 当前执行： G1 F2040 X18.921 Y17.449 E204.84337
# 加工进度： 50.0
# 加工进度： 50.0
# 当前执行： G1 X38.521 Y17.449 E205.82121
# 加工进度： 50.2
# 加工进度： 50.2
# 当前执行： G1 X38.521 Y37.049 E206.79906
# 加工进度： 50.4
# 加工进度： 50.4
# 当前执行： G1 X18.921 Y37.049 E207.77691
# 加工进度： 50.5
# 加工进度： 50.5
# 当前执行： G0 F6000 X19.460 Y36.259
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.731 Y17.988 E209.06603
# 加工进度： 51.0
# 加工进度： 51.0
# 当前执行： G0 F6000 X37.980 Y18.305
# 当前执行： G1 F2040 X19.777 Y36.508 E210.35035
# 加工进度： 51.4
# 加工进度： 51.4
# 当前执行： G0 F6000 X19.460 Y35.693
# 当前执行： G1 F2040 X37.165 Y17.988 E211.59953
# 加工进度： 51.7
# 加工进度： 51.7
# 当前执行： G0 F6000 X36.599 Y17.988
# 当前执行： G1 F2040 X19.460 Y35.127 E212.80878
# 加工进度： 52.1
# 加工进度： 52.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y34.561
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X36.034 Y17.988 E213.97813
# 加工进度： 52.4
# 加工进度： 52.4
# 当前执行： G0 F6000 X35.468 Y17.988
# 当前执行： G1 F2040 X19.460 Y33.996 E215.10758
# 加工进度： 52.7
# 加工进度： 52.7
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y33.430
# 当前执行： G1 F2040 X34.902 Y17.988 E216.19710
# 加工进度： 53.1
# 加工进度： 53.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X34.337 Y17.988
# 当前执行： G1 F2040 X19.460 Y32.864 E217.24672
# 加工进度： 53.4
# 加工进度： 53.4
# 当前执行： G0 F6000 X19.460 Y32.299
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X33.771 Y17.988 E218.25643
# 加工进度： 53.8
# 加工进度： 53.8
# 当前执行： G0 F6000 X33.205 Y17.988
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y31.733 E219.22622
# 加工进度： 54.1
# 加工进度： 54.1
# 当前执行： G0 F6000 X19.460 Y31.167
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X32.640 Y17.988 E220.15610
# 加工进度： 54.4
# 加工进度： 54.4
# 当前执行： G0 F6000 X32.074 Y17.988
# 当前执行： G1 F2040 X19.460 Y30.602 E221.04609
# 加工进度： 54.8
# 加工进度： 54.8
# 当前执行： G0 F6000 X19.460 Y30.036
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X31.508 Y17.988 E221.89614
# 加工进度： 55.1
# 加工进度： 55.1
# 当前执行： G0 F6000 X30.942 Y17.988
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y29.470 E222.70626
# 加工进度： 55.4
# 加工进度： 55.4
# 当前执行： G0 F6000 X19.460 Y28.905
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X30.377 Y17.988 E223.47651
# 加工进度： 55.8
# 加工进度： 55.8
# 当前执行： G0 F6000 X29.811 Y17.988
# 当前执行： G1 F2040 X19.460 Y28.339 E224.20683
# 加工进度： 56.1
# 加工进度： 56.1
# 当前执行： G0 F6000 X19.460 Y27.773
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X29.245 Y17.988 E224.89721
# 加工进度： 56.5
# 加工进度： 56.5
# 当前执行： G0 F6000 X28.680 Y17.988
# 当前执行： G1 F2040 X19.460 Y27.208 E225.54773
# 加工进度： 56.8
# 加工进度： 56.8
# 当前执行： G0 F6000 X19.460 Y26.642
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X28.114 Y17.988 E226.15832
# 加工进度： 57.1
# 加工进度： 57.1
# 当前执行： G0 F6000 X27.548 Y17.988
# 当前执行： G1 F2040 X19.460 Y26.076 E226.72897
# <gcoder.GCode object at 0x14ef4d828>
# 加工进度： 57.5
# 加工进度： 57.5
# 当前执行： G0 F6000 X19.460 Y25.510
# 当前执行： G1 F2040 X26.983 Y17.988 E227.25973
# 加工进度： 57.8
# 加工进度： 57.8
# 当前执行： G0 F6000 X26.417 Y17.988
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y24.945 E227.75058
# 加工进度： 58.2
# 加工进度： 58.2
# 当前执行： G0 F6000 X19.460 Y24.379
# 当前执行： G1 F2040 X25.851 Y17.988 E228.20150
# 加工进度： 58.5
# 加工进度： 58.5
# 当前执行： G0 F6000 X25.286 Y17.988
# 当前执行： G1 F2040 X19.460 Y23.813 E228.61252
# 加工进度： 58.8
# 加工进度： 58.8
# 当前执行： G0 F6000 X19.460 Y23.248
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X24.720 Y17.988 E228.98364
# 加工进度： 59.2
# 加工进度： 59.2
# 当前执行： G0 F6000 X24.154 Y17.988
# 当前执行： G1 F2040 X19.460 Y22.682 E229.31483
# 加工进度： 59.5
# 加工进度： 59.5
# 当前执行： G0 F6000 X19.460 Y22.116
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X23.589 Y17.988 E229.60612
# 加工进度： 59.8
# 加工进度： 59.8
# 当前执行： G0 F6000 X23.023 Y17.988
# 当前执行： G1 F2040 X19.460 Y21.551 E229.85751
# 加工进度： 60.2
# 加工进度： 60.2
# 当前执行： G0 F6000 X19.460 Y20.985
# 当前执行： G1 F2040 X22.457 Y17.988 E230.06896
# 加工进度： 60.5
# 加工进度： 60.5
# 当前执行： G0 F6000 X21.892 Y17.988
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y20.419 E230.24052
# 加工进度： 60.9
# 加工进度： 60.9
# 当前执行： G0 F6000 X19.460 Y19.854
# 当前执行： G1 F2040 X21.326 Y17.988 E230.37217
# 加工进度： 61.2
# 加工进度： 61.2
# 当前执行： G0 F6000 X20.760 Y17.988
# 当前执行： G1 F2040 X19.460 Y19.288 E230.46389
# 加工进度： 61.5
# 加工进度： 61.5
# 当前执行： G0 F6000 X19.460 Y18.722
# 当前执行： G1 F2040 X20.194 Y17.988 E230.51568
# 加工进度： 61.9
# 加工进度： 61.9
# 当前执行： G0 F6000 X37.980 Y18.871
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X20.342 Y36.508 E231.76010
# 加工进度： 62.2
# 加工进度： 62.2
# 当前执行： G0 F6000 X20.908 Y36.508
# 当前执行： G1 F2040 X37.980 Y19.436 E232.96462
# 加工进度： 62.6
# 加工进度： 62.6
# 当前执行： G0 F6000 X37.980 Y20.002
# 当前执行： G1 F2040 X21.474 Y36.508 E234.12921
# 加工进度： 62.9
# 加工进度： 62.9
# 当前执行： G0 F6000 X22.039 Y36.508
# 当前执行： G1 F2040 X37.980 Y20.568 E235.25390
# 加工进度： 63.2
# 加工进度： 63.2
# 当前执行： G0 F6000 X37.980 Y21.134
# 当前执行： G1 F2040 X22.605 Y36.508 E236.33865
# 加工进度： 63.6
# 加工进度： 63.6
# 当前执行： G0 F6000 X23.171 Y36.508
# 当前执行： G1 F2040 X37.980 Y21.699 E237.38351
# 加工进度： 63.9
# 加工进度： 63.9
# 当前执行： G0 F6000 X37.980 Y22.265
# 当前执行： G1 F2040 X23.736 Y36.508 E238.38847
# 加工进度： 64.2
# 加工进度： 64.2
# 当前执行： G0 F6000 X24.302 Y36.508
# 当前执行： G1 F2040 X37.980 Y22.831 E239.35349
# 加工进度： 64.6
# 加工进度： 64.6
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X37.980 Y23.396
# 当前执行： G1 F2040 X24.868 Y36.508 E240.27861
# 加工进度： 64.9
# 加工进度： 64.9
# 当前执行： G0 F6000 X25.433 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y23.962 E241.16383
# 加工进度： 65.3
# 加工进度： 65.3
# 当前执行： G0 F6000 X37.980 Y24.528
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X25.999 Y36.508 E242.00912
# 加工进度： 65.6
# 加工进度： 65.6
# 当前执行： G0 F6000 X26.565 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y25.093 E242.81451
# 加工进度： 65.9
# 加工进度： 65.9
# 当前执行： G0 F6000 X37.980 Y25.659
# 当前执行： G1 F2040 X27.130 Y36.508 E243.58000
# 加工进度： 66.3
# 加工进度： 66.3
# 当前执行： G0 F6000 X27.696 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y26.225 E244.30556
# 加工进度： 66.6
# 加工进度： 66.6
# 当前执行： G0 F6000 X37.980 Y26.790
# 当前执行： G1 F2040 X28.262 Y36.508 E244.99122
# 加工进度： 67.0
# 加工进度： 67.0
# 当前执行： G0 F6000 X28.827 Y36.509
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y27.356 E245.63701
# 加工进度： 67.3
# 加工进度： 67.3
# 当前执行： G0 F6000 X37.980 Y27.922
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X29.393 Y36.509 E246.24287
# 加工进度： 67.6
# 加工进度： 67.6
# 当前执行： G0 F6000 X29.958 Y36.509
# 当前执行： G1 F2040 X37.980 Y28.487 E246.80886
# 加工进度： 68.0
# 加工进度： 68.0
# 当前执行： G0 F6000 X37.980 Y29.053
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X30.524 Y36.509 E247.33493
# 加工进度： 68.3
# 加工进度： 68.3
# 当前执行： G0 F6000 X31.090 Y36.509
# 当前执行： G1 F2040 X37.980 Y29.619 E247.82105
# 加工进度： 68.6
# 加工进度： 68.6
# 当前执行： G0 F6000 X37.980 Y30.184
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X31.655 Y36.509 E248.26731
# 加工进度： 69.0
# 加工进度： 69.0
# 当前执行： G0 F6000 X32.221 Y36.509
# 当前执行： G1 F2040 X37.980 Y30.750 E248.67364
# 加工进度： 69.3
# 加工进度： 69.3
# 当前执行： G0 F6000 X37.980 Y31.316
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X32.787 Y36.509 E249.04004
# 加工进度： 69.7
# 加工进度： 69.7
# 当前执行： G0 F6000 X33.352 Y36.509
# 当前执行： G1 F2040 X37.980 Y31.882 E249.36653
# 加工进度： 70.0
# 加工进度： 70.0
# 当前执行： G0 F6000 X37.980 Y32.447
# 当前执行： G1 F2040 X33.918 Y36.509 E249.65313
# 加工进度： 70.3
# 加工进度： 70.3
# 当前执行： G0 F6000 X34.484 Y36.509
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y33.013 E249.89979
# 加工进度： 70.7
# 加工进度： 70.7
# 当前执行： G0 F6000 X37.980 Y33.579
# 当前执行： G1 F2040 X35.049 Y36.509 E250.10655
# 加工进度： 71.0
# 加工进度： 71.0
# 当前执行： G0 F6000 X35.615 Y36.509
# 当前执行： G1 F2040 X37.980 Y34.144 E250.27342
# 加工进度： 71.4
# 加工进度： 71.4
# 当前执行： G0 F6000 X37.980 Y34.710
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X36.181 Y36.509 E250.40035
# 加工进度： 71.7
# 加工进度： 71.7
# 当前执行： G0 F6000 X36.746 Y36.509
# 当前执行： G1 F2040 X37.980 Y35.276 E250.48738
# 加工进度： 72.0
# 加工进度： 72.0
# 当前执行： G0 F6000 X37.980 Y35.841
# 当前执行： G1 F2040 X37.312 Y36.509 E250.53451
# 加工进度： 72.4
# 加工进度： 72.4
# 当前执行： G0 F6000 X37.878 Y36.509
# 当前执行： G1 F2040 X37.980 Y36.407 E250.54170
# 加工进度： 72.7
# 加工进度： 72.7
# 当前执行： G0 F6000 X19.629 Y17.988
# 当前执行： G1 F2040 X19.460 Y18.157 E250.55363
# 加工进度： 73.0
# 加工进度： 73.0
# 当前执行： G0 F6000 X19.321 Y17.849 Z0.900
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2220 X38.121 Y17.849 E251.49156
# 加工进度： 73.7
# 加工进度： 73.7
# 当前执行： G1 X38.121 Y36.649 E252.42950
# 加工进度： 73.9
# 加工进度： 73.9
# 当前执行： G1 X19.321 Y36.649 E253.36743
# 加工进度： 74.1
# 加工进度： 74.1
# 当前执行： G1 X19.321 Y17.849 E254.30537
# 加工进度： 74.2
# 加工进度： 74.2
# 当前执行： G0 F6000 X18.921 Y17.449
# 当前执行： G1 F2040 X38.521 Y17.449 E255.28322
# 加工进度： 74.7
# 加工进度： 74.7
# 当前执行： G1 X38.521 Y37.049 E256.26107
# 加工进度： 74.9
# 加工进度： 74.9
# 当前执行： G1 X18.921 Y37.049 E257.23891
# 加工进度： 75.1
# 加工进度： 75.1
# 当前执行： G1 X18.921 Y17.449 E258.21676
# 加工进度： 75.2
# 加工进度： 75.2
# 当前执行： G0 F6000 X19.460 Y18.046
# 当前执行： G1 F2040 X37.922 Y36.508 E259.51936
# 加工进度： 75.8
# 加工进度： 75.8
# 当前执行： G0 F6000 X37.980 Y36.000
# 当前执行： G1 F2040 X19.969 Y17.989 E260.79013
# 加工进度： 76.1
# 加工进度： 76.1
# 当前执行： G0 F6000 X19.460 Y18.611
# 当前执行： G1 F2040 X37.357 Y36.508 E262.05286
# 加工进度： 76.4
# 加工进度： 76.4
# 当前执行： G0 F6000 X36.791 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y19.177 E263.27566
# 加工进度： 76.8
# 加工进度： 76.8
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X19.460 Y19.743
# 当前执行： G1 F2040 X36.225 Y36.508 E264.45852
# 加工进度： 77.1
# 加工进度： 77.1
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G0 F6000 X35.660 Y36.508
# 当前执行： G1 F2040 X19.460 Y20.308 E265.60151
# 加工进度： 77.4
# 加工进度： 77.4
# 当前执行： G0 F6000 X19.460 Y20.874
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X35.094 Y36.508 E266.70458
# 加工进度： 77.8
# 加工进度： 77.8
# 当前执行： G0 F6000 X34.528 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y21.440 E267.76771
# 加工进度： 78.1
# 加工进度： 78.1
# 当前执行： G0 F6000 X19.460 Y22.005
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X33.963 Y36.508 E268.79097
# 加工进度： 78.5
# 加工进度： 78.5
# 当前执行： G0 F6000 X33.397 Y36.508
# 当前执行： G1 F2040 X19.460 Y22.571 E269.77430
# 加工进度： 78.8
# 加工进度： 78.8
# 当前执行： G0 F6000 X19.460 Y23.137
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X32.831 Y36.508 E270.71770
# 加工进度： 79.1
# 加工进度： 79.1
# 当前执行： G0 F6000 X32.265 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y23.702 E271.62120
# 加工进度： 79.5
# 加工进度： 79.5
# 当前执行： G0 F6000 X19.460 Y24.268
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X31.700 Y36.508 E272.48479
# 加工进度： 79.8
# 加工进度： 79.8
# 当前执行： G0 F6000 X31.134 Y36.508
# 当前执行： G1 F2040 X19.460 Y24.834 E273.30846
# 加工进度： 80.2
# 加工进度： 80.2
# 当前执行： G0 F6000 X19.460 Y25.399
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X30.568 Y36.508 E274.09222
# 加工进度： 80.5
# 加工进度： 80.5
# 当前执行： G0 F6000 X30.003 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y25.965 E274.83609
# 加工进度： 80.8
# 加工进度： 80.8
# 当前执行： G0 F6000 X19.460 Y26.531
# 当前执行： G1 F2040 X29.437 Y36.508 E275.54002
# 加工进度： 81.2
# 加工进度： 81.2
# 当前执行： G0 F6000 X28.871 Y36.508
# <gcoder.GCode object at 0x14ef4d828>
# 20.0
# 当前执行： G1 F2040 X19.460 Y27.097 E276.20402
# 加工进度： 81.5
# 加工进度： 81.5
# 当前执行： G0 F6000 X19.460 Y27.662
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X28.305 Y36.507 E276.82808
# 加工进度： 81.8
# 加工进度： 81.8
# 当前执行： G0 F6000 X27.739 Y36.507
# 当前执行： G1 F2040 X19.460 Y28.228 E277.41221
# 加工进度： 82.2
# 加工进度： 82.2
# 当前执行： G0 F6000 X19.460 Y28.794
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X27.174 Y36.507 E277.95644
# 加工进度： 82.5
# 加工进度： 82.5
# 当前执行： G0 F6000 X26.608 Y36.507
# 当前执行： G1 F2040 X19.460 Y29.359 E278.46077
# 加工进度： 82.9
# 加工进度： 82.9
# 当前执行： G0 F6000 X19.460 Y29.925
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X26.042 Y36.507 E278.92516
# 加工进度： 83.2
# 加工进度： 83.2
# 当前执行： G0 F6000 X25.477 Y36.507
# 当前执行： G1 F2040 X19.460 Y30.491 E279.34966
# 加工进度： 83.5
# 加工进度： 83.5
# 当前执行： G0 F6000 X19.460 Y31.056
# 当前执行： G1 F2040 X24.911 Y36.507 E279.73425
# 加工进度： 83.9
# 加工进度： 83.9
# 当前执行： G0 F6000 X24.345 Y36.507
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y31.622 E280.07892
# 加工进度： 84.2
# 加工进度： 84.2
# 当前执行： G0 F6000 X19.460 Y32.188
# 当前执行： G1 F2040 X23.780 Y36.507 E280.38368
# 加工进度： 84.6
# 加工进度： 84.6
# 当前执行： G0 F6000 X23.214 Y36.507
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X19.460 Y32.753 E280.64855
# 加工进度： 84.9
# 加工进度： 84.9
# 当前执行： G0 F6000 X19.460 Y33.319
# 当前执行： G1 F2040 X22.648 Y36.507 E280.87348
# 加工进度： 85.2
# 加工进度： 85.2
# 当前执行： G0 F6000 X22.082 Y36.507
# 当前执行： G1 F2040 X19.460 Y33.885 E281.05847
# 加工进度： 85.6
# 加工进度： 85.6
# 当前执行： G0 F6000 X19.460 Y34.450
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X21.517 Y36.507 E281.20361
# 加工进度： 85.9
# 加工进度： 85.9
# 当前执行： G0 F6000 X20.951 Y36.507
# 当前执行： G1 F2040 X19.460 Y35.016 E281.30880
# 加工进度： 86.2
# 加工进度： 86.2
# 当前执行： G0 F6000 X19.460 Y35.582
# 当前执行： G1 F2040 X20.385 Y36.507 E281.37407
# 加工进度： 86.6
# 加工进度： 86.6
# 当前执行： G0 F6000 X37.980 Y35.434
# 当前执行： G1 F2040 X20.535 Y17.989 E282.60491
# 加工进度： 86.9
# 加工进度： 86.9
# 当前执行： G0 F6000 X21.100 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y34.868 E283.79585
# 加工进度： 87.3
# 加工进度： 87.3
# 当前执行： G0 F6000 X37.980 Y34.303
# 当前执行： G1 F2040 X21.666 Y17.989 E284.94689
# 加工进度： 87.6
# 加工进度： 87.6
# 当前执行： G0 F6000 X22.232 Y17.989
# 当前执行： G1 F2040 X37.980 Y33.737 E286.05799
# 加工进度： 87.9
# 加工进度： 87.9
# 当前执行： G0 F6000 X37.980 Y33.171
# 当前执行： G1 F2040 X22.797 Y17.989 E287.12920
# 加工进度： 88.3
# 加工进度： 88.3
# 当前执行： G0 F6000 X23.363 Y17.989
# 当前执行： G1 F2040 X37.980 Y32.606 E288.16051
# 加工进度： 88.6
# 加工进度： 88.6
# 当前执行： G0 F6000 X37.980 Y32.040
# 当前执行： G1 F2040 X23.929 Y17.989 E289.15188
# 加工进度： 89.0
# 加工进度： 89.0
# 当前执行： G0 F6000 X24.494 Y17.989
# 当前执行： G1 F2040 X37.980 Y31.474 E290.10336
# 加工进度： 89.3
# 加工进度： 89.3
# 当前执行： G0 F6000 X37.980 Y30.909
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X25.060 Y17.989 E291.01493
# 加工进度： 89.6
# 加工进度： 89.6
# 当前执行： G0 F6000 X25.626 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y30.343 E291.88658
# 加工进度： 90.0
# 加工进度： 90.0
# 当前执行： G0 F6000 X37.980 Y29.777
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X26.191 Y17.989 E292.71832
# 加工进度： 90.3
# 加工进度： 90.3
# 当前执行： G0 F6000 X26.757 Y17.989
# 当前执行： G1 F2040 X37.980 Y29.211 E293.51013
# 加工进度： 90.6
# 加工进度： 90.6
# 当前执行： G0 F6000 X37.980 Y28.646
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X27.323 Y17.989 E294.26204
# 加工进度： 91.0
# 加工进度： 91.0
# 当前执行： G0 F6000 X27.888 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y28.080 E294.97405
# 加工进度： 91.3
# 加工进度： 91.3
# 当前执行： G0 F6000 X37.980 Y27.514
# 当前执行： G1 F2040 X28.454 Y17.989 E295.64612
# 加工进度： 91.7
# 加工进度： 91.7
# 当前执行： G0 F6000 X29.020 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y26.949 E296.27830
# 加工进度： 92.0
# 加工进度： 92.0
# 当前执行： G0 F6000 X37.980 Y26.383
# 当前执行： G1 F2040 X29.586 Y17.989 E296.87054
# 加工进度： 92.3
# 加工进度： 92.3
# 当前执行： G0 F6000 X30.151 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y25.817 E297.42288
# 加工进度： 92.7
# 加工进度： 92.7
# 当前执行： G0 F6000 X37.980 Y25.252
# 当前执行： G1 F2040 X30.717 Y17.989 E297.93533
# 加工进度： 93.0
# 加工进度： 93.0
# 当前执行： G0 F6000 X31.283 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y24.686 E298.40784
# 加工进度： 93.4
# 加工进度： 93.4
# 当前执行： G0 F6000 X37.980 Y24.120
# 当前执行： G1 F2040 X31.848 Y17.989 E298.84045
# 加工进度： 93.7
# 加工进度： 93.7
# 当前执行： G0 F6000 X32.414 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y23.555 E299.23316
# 加工进度： 94.0
# 加工进度： 94.0
# 当前执行： G0 F6000 X37.980 Y22.989
# 当前执行： G1 F2040 X32.980 Y17.989 E299.58593
# 加工进度： 94.4
# 加工进度： 94.4
# 当前执行： G0 F6000 X33.545 Y17.989
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.980 Y22.423 E299.89881
# 加工进度： 94.7
# 加工进度： 94.7
# 当前执行： G0 F6000 X37.980 Y21.858
# 当前执行： G1 F2040 X34.111 Y17.989 E300.17179
# 加工进度： 95.0
# 加工进度： 95.0
# 当前执行： G0 F6000 X34.677 Y17.989
# 当前执行： G1 F2040 X37.980 Y21.292 E300.40484
# 加工进度： 95.4
# 加工进度： 95.4
# 当前执行： G0 F6000 X37.980 Y20.726
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X35.242 Y17.989 E300.59798
# 加工进度： 95.7
# 加工进度： 95.7
# 当前执行： G0 F6000 X35.808 Y17.989
# 当前执行： G1 F2040 X37.980 Y20.161 E300.75123
# 加工进度： 96.1
# 加工进度： 96.1
# 当前执行： G0 F6000 X37.980 Y19.595
# 当前执行： G1 F2040 X36.374 Y17.989 E300.86454
# 加工进度： 96.4
# 加工进度： 96.4
# 当前执行： G0 F6000 X36.939 Y17.989
# 当前执行： G1 F2040 X37.980 Y19.029 E300.93795
# 加工进度： 96.7
# 加工进度： 96.7
# 当前执行： G0 F6000 X37.980 Y18.463
# <gcoder.GCode object at 0x14ef4d828>
# 当前执行： G1 F2040 X37.505 Y17.989 E300.97143
# 加工进度： 97.1
# 加工进度： 97.1
# 当前执行： G0 F6000 X19.460 Y36.148
# 当前执行： G1 F2040 X19.820 Y36.507 E300.99680
# 加工进度： 97.4
# 加工进度： 97.4
# 当前执行： M107
# 当前执行： G1 F6000 E297.99680
# 加工进度： 97.8
# 加工进度： 97.8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# IndexError: list index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# IndexError: list index out of range
# 当前执行： G0 X19.820 Y36.507 Z6.000
# 当前执行： M107
# 当前执行： G91
# 当前执行： T0
# 当前执行： G1 E-1
# 加工进度： 99.1
# 加工进度： 99.1
# 当前执行： M104 T0 S0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# IndexError: list index out of range
# 当前执行： G90
# 当前执行： G92 E0
# 当前执行： M140 S0
# 当前执行： M84
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# <gcoder.GCode object at 0x14ef4d828>
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
#     475             self.tool_4.setStyleSheet(r"QPushButton{background-image:url(resource/ToolBar/begin_disabled.png)}")
#
# UnboundLocalError: local variable 'layer' referenced before assignment
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-1-f7b9f8a867a2> in printint_status(self)
#     471                 self.slider_layer.setValue(layer-1)
#     472             #设置加工高度
# --> 473             self.label_process_layer.setText("%.2f mm"%self.printer.layer_height[layer-2])
#     474             self.tool_4.setEnabled(False)
# ...
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>
# <gcoder.GCode object at 0x14ef4d828>

# %%
dir(QtWidgets.QDialogButtonBox)

# %% [markdown]
# ###
